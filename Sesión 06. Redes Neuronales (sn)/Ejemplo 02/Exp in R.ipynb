# %% [markdown]
# # Ahora usemos R para generar un análisis exploratorio de datos

# %%
library(ggplot2)
library(dplyr)

# %% [markdown]
# # Hagamos un histograma con ggplot2 de las edades

# %%
data = read.csv("pima-indians-diabetes-for-R.csv")

data %>% ggplot(aes(x= edad)) +
  geom_histogram() +
  geom_vline(aes(xintercept=mean(data$edad)),
            color="blue", linetype="dashed", size=1) +
  geom_histogram(color="black", fill="white") +
  geom_histogram(aes(y=..density..), colour="black", fill="white")+
  geom_density(alpha=.2, fill="#FF6666")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# # Exploremos los casos observados de diabetes

# %%
data %>% ggplot(aes(x= dummy)) +
  geom_bar()
# Out:
# plot without title

# %% [markdown]
# # Exploremos la presión sanguínea y la glucosa

# %%
data %>% ggplot(aes(x= presion)) +
  geom_histogram() +
  geom_vline(aes(xintercept=mean(data$presion)),
            color="blue", linetype="dashed", size=1) +
  geom_histogram(color="black", fill="white") +
  geom_histogram(aes(y=..density..), colour="black", fill="white")+
  geom_density(alpha=.2, fill="#FF6666")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
data %>% ggplot(aes(x= glucosa)) +
  geom_histogram() +
  geom_vline(aes(xintercept=mean(data$glucosa)),
            color="blue", linetype="dashed", size=1) +
  geom_histogram(color="black", fill="white") +
  geom_histogram(aes(y=..density..), colour="black", fill="white")+
  geom_density(alpha=.2, fill="#FF6666")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
